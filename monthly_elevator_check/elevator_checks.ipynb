# %% [markdown]
# ## Elevator Check Data Appending
#
# Appending daily elevator check data from blockbyblock to compile a monthly Excel report to work with

# %% [markdown]
# #### How it works:
#  Get all CSVs from current directory and read into a df
#
# PROS:
# * can dynamically read the files, regardless of whether the filename changed or not
#
# CONS:
#  * assumes that all the files are located in this filepath
#  * assumes that the only CSVs in this file are relevant

# %%
import datetime as date
import pandas as pd
import os
from os import listdir
from os.path import isfile, join
import pathlib

# get filepath for this file
mypath = pathlib.Path().resolve()

# get all files from the current directory 
all_csvs = [f for f in listdir(mypath) if (isfile(join(mypath, f)) and f.endswith('.csv'))]

all_csvs
# Out:
# ['Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (1).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (10).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (11).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (12).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (13).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (14).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (15).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (16).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (17).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (18).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (19).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (2).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (20).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (21).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (22).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (23).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (24).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (25).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (26).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (27).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (28).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (29).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (3).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (30).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (31).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (32).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (33).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (34).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (35).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (36).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (37).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (38).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (39).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (4).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (40).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (41).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (42).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (43).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (44).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (45).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (46).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (47).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (48).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (49).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (5).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (50).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (51).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (52).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (53).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (54).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (55).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (56).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (57).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (58).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (59).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (6).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (60).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (61).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (62).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (63).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (64).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (65).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (66).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (67).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (68).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (69).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (7).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (70).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (71).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (72).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (73).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (74).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (75).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (76).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (77).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (78).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (79).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (8).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (80).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (81).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (82).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (83).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22 (9).csv',
#  'Stats Day View - 2022-12-22.csv_massachusetts-bay-transportation-authority_2022_12_22.csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (1).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (10).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (11).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (12).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (13).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (14).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (15).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (16).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (17).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (18).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (19).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (2).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (20).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (21).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (22).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (23).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (24).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (25).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (26).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (27).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (28).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (29).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (3).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (30).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (31).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (32).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (33).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (34).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (35).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (36).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (37).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (38).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (39).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (4).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (40).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (41).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (5).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (6).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (7).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (8).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03 (9).csv',
#  'Stats Day View - 2023-01-03.csv_massachusetts-bay-transportation-authority_2023_01_03.csv']

# %%
# function that reads the file from the FileNames list and makes it become a dataFrame
def get_df(fname):
    df = pd.read_csv(fname)
    return df

# for each csv file, read into a dataframe in df list
df = [get_df(file) for file in all_csvs]
# concatenate all dfs
full_df = pd.concat(df)

full_df
# Out:
#                         User                    Time  Amount           Zone  \
# 0           MBTA Sean Brogan  12/01/2022 07:00:48 PM     1.0  Central South
# 1    MBTA Jefferson Da Silva  12/01/2022 07:00:44 PM     1.0       Maverick
# 2    MBTA Ronnie  Washington  12/01/2022 07:00:44 PM     1.0         Andrew
# 3      MBTA Dashawn  Jenkins  12/01/2022 07:00:27 PM     1.0        Jackson
# 4          MBTA Gary Philipo  12/01/2022 07:00:09 PM     4.0    Copley West
# ..                       ...                     ...     ...            ...
# 995        MBTA Rey Santiago  12/22/2022 07:29:23 PM     1.0       Gov Cntr
# 996        MBTA Devon  Henry  12/22/2022 07:29:14 PM     1.0      Park West
# 997   MBTA Nicholas  Hollins  12/22/2022 07:29:08 PM     1.0    Charles/MGH
# 998         MBTA Troy  Lomax  12/22/2022 07:29:05 PM     1.0          Tufts
# 999       MBTA Brian  Ringer  12/22/2022 07:28:58 PM     1.0        Ruggles
#
#     Operable / Non-Operable Status      Response     Notes  \
# 0                  Operable  Clean  No-call-made      Insp
# 1                  Operable  Clean  No-call-made        Ok
# 2                  Operable  Clean  No-call-made     Clean
# 3                  Operable  Clean  No-call-made        Ok
# 4                  Operable  Clean  No-call-made        Ok
# ..                      ...    ...           ...       ...
# 995                Operable  Clean  No-call-made  No issue
# 996                Operable  Clean  No-call-made     Clean
# 997                Operable  Clean  No-call-made        Ok
# 998                Operable  Clean  No-call-made     Clean
# 999                Operable  Clean  No-call-made     Clean
#
#      Elevator Unit ID #          If Non-Operable        If Out of Service
# 0           Central 861  Out of Service Sign: No  Out of Service Sign: No
# 1          Maverick 965                      NaN                      NaN
# 2            Andrew 872  Out of Service Sign: No  Out of Service Sign: No
# 3    Jackson Square 846  Out of Service Sign: No  Out of Service Sign: No
# 4            Copley 977  Out of Service Sign: No  Out of Service Sign: No
# ..                  ...                      ...                      ...
# 995    Gov't Center 721  Out of Service Sign: No  Out of Service Sign: No
# 996     Park Street 979                      NaN                      NaN
# 997     Charles/MGH 952  Out of Service Sign: No  Out of Service Sign: No
# 998           Tufts 858  Out of Service Sign: No  Out of Service Sign: No
# 999         Ruggles 728  Out of Service Sign: No  Out of Service Sign: No
#
# [111603 rows x 11 columns]

# %%
# get today's date and generate the filename containing month and year
today = date.datetime.now()
first = today.replace(day=1)
last_month = first - date.timedelta(days=1)
export_name = "Elevator Checks - " + last_month.strftime("%b") + " " + str(last_month.year) + ".xlsx"

# directory to output
outdir = './output'
if not os.path.exists(outdir): # if output folder doesn't exist in directory
    os.mkdir(outdir) # make folder

# create final path
fullpath = os.path.join(outdir, export_name)    

# export to csv in output folder
full_df.to_excel(fullpath, index=False)

# %%
full_df
# Out:
#                          User                    Time  Amount            Zone  \
# 0        MBTA Amanda  Burnell  09/01/2022 12:43:47 PM     6.0           Davis
# 1    MBTA Jhony Orantes-Rodas  09/01/2022 12:43:42 PM     1.0       Park West
# 2            MBTA April Scott  09/01/2022 12:43:40 PM     1.0   Ashmont North
# 3        MBTA Leonard  Orcutt  09/01/2022 12:43:36 PM     1.0       Arlington
# 4        MBTA Amanda  Burnell  09/01/2022 12:43:28 PM     6.0           Davis
# ..                        ...                     ...     ...             ...
# 995        MBTA Camille Burke  09/27/2022 06:26:39 PM     1.0       Park West
# 996        MBTA Joelson  Noel  09/27/2022 06:25:57 PM     1.0   North Station
# 997       MBTA Luis  Villegas  09/27/2022 06:25:56 PM     1.0  Assembly North
# 998      MBTA Imani  Hamilton  09/27/2022 06:25:55 PM     3.0      Wellington
# 999   MBTA Anurag  Budhathoki  09/27/2022 06:25:35 PM     1.0          Porter
#
#     Operable / Non-Operable Status      Response      Notes  \
# 0                  Operable  Clean  No-call-made      Clean
# 1                  Operable  Clean  No-call-made          C
# 2                  Operable  Clean  No-call-made    12:43pm
# 3                  Operable  Clean  No-call-made        Chk
# 4                  Operable  Clean  No-call-made      Clean
# ..                      ...    ...           ...        ...
# 995                Operable  Clean  No-call-made    Cleaned
# 996                Operable  Clean  No-call-made         Ok
# 997                Operable  Clean  No-call-made      Clean
# 998                Operable  Clean  No-call-made          N
# 999                Operable  Clean  No-call-made  No issues
#
#     Elevator Unit ID #          If Non-Operable        If Out of Service
# 0            Davis 817                      NaN                      NaN
# 1      Park Street 823                      NaN                      NaN
# 2          Ashmont 968                      NaN                      NaN
# 3        Arlington 964                      NaN                      NaN
# 4            Davis 816                      NaN                      NaN
# ..                 ...                      ...                      ...
# 995    Park Street 823  Out of Service Sign: No  Out of Service Sign: No
# 996  North Station 912  Out of Service Sign: No  Out of Service Sign: No
# 997       Assembly 716                      NaN                      NaN
# 998     Wellington 864  Out of Service Sign: No  Out of Service Sign: No
# 999         Porter 987                      NaN                      NaN
#
# [57123 rows x 11 columns]
